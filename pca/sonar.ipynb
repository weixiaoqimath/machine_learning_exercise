# %%
# The shape of sonar data is 208*60
#https://archive.ics.uci.edu/ml/datasets/Connectionist+Bench+(Sonar,+Mines+vs.+Rocks)
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import mglearn
import numpy as np
import pandas as pd
sonar = pd.read_csv("sonar.csv", header =None)
np_sonar = sonar.to_numpy()

data = np_sonar[:, :60]
target = np_sonar[:,60]

# %%
print(data.shape)
# Out:
# (208, 60)

# %%
display(target)
# Out:
# array(['R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R',
#        'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R',
#        'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R',
#        'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R',
#        'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R',
#        'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R',
#        'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R',
#        'R', 'R', 'R', 'R', 'R', 'R', 'M', 'M', 'M', 'M', 'M', 'M', 'M',
#        'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M',
#        'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M',
#        'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M',
#        'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M',
#        'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M',
# ...

# %%
from sklearn.decomposition import PCA
# keep the first two principal components of the data 
unscaled_pca = PCA(n_components=0.85, svd_solver = 'full')
# fit PCA model to breast cancer data 
unscaled_pca.fit(data)
# transform data onto the first two principal components
unscaledX_pca = unscaled_pca.transform(data)
print("Original shape: {}".format(str(data.shape))) 
print("Reduced shape: {}".format(str(unscaledX_pca.shape)))
print("Explained variance ratio: {}".format(unscaled_pca.explained_variance_ratio_))

plt.figure(figsize=(8, 8))
mglearn.discrete_scatter(unscaledX_pca[:, 0], unscaledX_pca[:, 1], target) 
#plt.legend(, loc="best") 
plt.gca().set_aspect("equal")
plt.xlabel("First principal component")
plt.ylabel("Second principal component")
# Out:
# Original shape: (208, 60)
# Reduced shape: (208, 9)
# Explained variance ratio: [0.31971149 0.2038306  0.0855582  0.06459322 0.05164156 0.04451402
#  0.04207696 0.02632652 0.02230037]
# Text(0, 0.5, 'Second principal component')

# %%
scaler = StandardScaler() 
scaler.fit(data)
data_scaled = scaler.transform(data)
#num_class = 2
pca = PCA(n_components=0.85, svd_solver = 'full')

pca.fit(data_scaled)
# transform data onto the first two principal components
X_pca = pca.transform(data_scaled)
print("Original shape: {}".format(str(data.shape))) 
print("Reduced shape: {}".format(str(X_pca.shape)))
print("Explained variance ratio: {}".format(pca.explained_variance_ratio_))

plt.figure(figsize=(8, 8))
mglearn.discrete_scatter(X_pca[:, 0], X_pca[:, 1], target) 
#plt.legend(, loc="best") 
plt.gca().set_aspect("equal")
plt.xlabel("First principal component")
plt.ylabel("Second principal component")
# Out:
# Original shape: (208, 60)
# Reduced shape: (208, 17)
# Explained variance ratio: [0.20346557 0.18897216 0.08549989 0.0567919  0.0500708  0.04064995
#  0.03278992 0.03046466 0.02565961 0.02491102 0.0207528  0.0190199
#  0.0174698  0.01538484 0.01427797 0.01360959 0.01234608]
# Text(0, 0.5, 'Second principal component')
