# %%
import matplotlib.pyplot as plt

# %%
f1 = open('train-images-idx3-ubyte')
f2 = open('train-labels-idx1-ubyte')
f3 = open('t10k-images-idx3-ubyte')
f4 = open('t10k-labels-idx1-ubyte')

X_train_loaded = np.fromfile(file=f1, dtype=np.uint8)
y_train_loaded = np.fromfile(file=f2, dtype=np.uint8)
X_train = (X_train_loaded[16:].reshape((60000, 28, 28, 1)).astype(np.float32)/ 127.5 - 1).reshape(60000, 784)
y_train = y_train_loaded[8:].reshape((60000, 1)).astype(np.int32)
X_test_loaded = np.fromfile(file=f3, dtype=np.uint8)
y_test_loaded = np.fromfile(file=f4, dtype=np.uint8)
X_test = (X_test_loaded[16:].reshape((10000, 28, 28, 1)).astype(np.float32)/127.5 -1).reshape(10000, 784)
y_test = y_test_loaded[8:].reshape((10000, 1)).astype(np.int32)

# %%
# %run model.py

# %%
number = [0]

model = GAN(number, learning_rate=1e-3, decay_rate=1e-4, epochs=50)
J_Ds, J_Gs = model.train(x_train, y_train)
# Out:
# Epoch:0|G loss:1.3662|D loss:0.5496|D(G(z))avg:0.2624|D(x)avg:0.7861|LR:0.001000
# Epoch:5|G loss:0.7858|D loss:1.2209|D(G(z))avg:0.4563|D(x)avg:0.5431|LR:0.000999
# Epoch:10|G loss:0.7357|D loss:1.2991|D(G(z))avg:0.4793|D(x)avg:0.5241|LR:0.000996
# Epoch:15|G loss:0.7359|D loss:1.3291|D(G(z))avg:0.4791|D(x)avg:0.5083|LR:0.000990
# Epoch:20|G loss:0.7235|D loss:1.3380|D(G(z))avg:0.4851|D(x)avg:0.5096|LR:0.000981
# Epoch:25|G loss:0.7098|D loss:1.3539|D(G(z))avg:0.4918|D(x)avg:0.5081|LR:0.000970
# Epoch:30|G loss:0.7080|D loss:1.3536|D(G(z))avg:0.4927|D(x)avg:0.5092|LR:0.000957
# Epoch:35|G loss:0.7114|D loss:1.3489|D(G(z))avg:0.4910|D(x)avg:0.5099|LR:0.000942
# Epoch:40|G loss:0.7109|D loss:1.3501|D(G(z))avg:0.4912|D(x)avg:0.5095|LR:0.000925
# Epoch:45|G loss:0.7119|D loss:1.3511|D(G(z))avg:0.4907|D(x)avg:0.5085|LR:0.000906
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-59-16c197419aba> in <module>
#       2
#       3 model = GAN(number, learning_rate=1e-3, decay_rate=1e-4, epochs=100)
# ----> 4 J_Ds, J_Gs = model.train(x_train, y_train)
#
# ~/machine_learning_exercise/GAN/model.py in train(self, x, y)
#     372                 self.sample_images(x_fake, epoch, show=True)  # display sample images
#     373             else:
# --> 374                 self.sample_images(x_fake, epoch, show=False)
#     375
#     376             # reduce learning rate after every epoch
#
# ~/machine_learning_exercise/GAN/model.py in sample_images(self, images, epoch, show)
#     295
#     296         for i in range(16):
# --> 297             plt.subplot(4, 4, i + 1)
#     298             plt.imshow(images[i] * 127.5 + 127.5, cmap='gray')
#     299             plt.axis('off')
#
# ~/miniconda3/envs/py36/lib/python3.6/site-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1140
#    1141     fig = gcf()
# -> 1142     ax = fig.add_subplot(*args, **kwargs)
#    1143     bbox = ax.bbox
#    1144     axes_to_delete = []
#
# ~/miniconda3/envs/py36/lib/python3.6/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1400                     # more similar to add_axes.
#    1401                     self._axstack.remove(ax)
# -> 1402             ax = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1403
#    1404         return self._add_axes_internal(key, ax)
#
# ~/miniconda3/envs/py36/lib/python3.6/site-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      40         self.update_params()
#      41         # _axes_class is set in the subplot_class_factory
# ---> 42         self._axes_class.__init__(self, fig, self.figbox, **kwargs)
#      43         # add a layout box to this, for both the full axis, and the poss
#      44         # of the axis.  We need both because the axes may become smaller
#
# ~/miniconda3/envs/py36/lib/python3.6/site-packages/matplotlib/axes/_base.py in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, **kwargs)
#     509
#     510         self._rasterization_zorder = None
# --> 511         self.cla()
#     512
#     513         # funcs used to format x and y - fall back on major formatters
#
# ~/miniconda3/envs/py36/lib/python3.6/site-packages/matplotlib/axes/_base.py in cla(self)
#    1110         self.grid(False)  # Disable grid on init to use rcParameter
#    1111         self.grid(self._gridOn, which=mpl.rcParams['axes.grid.which'],
# -> 1112                   axis=mpl.rcParams['axes.grid.axis'])
#    1113         props = font_manager.FontProperties(
#    1114             size=mpl.rcParams['axes.titlesize'],
#
# ~/miniconda3/envs/py36/lib/python3.6/site-packages/matplotlib/axes/_base.py in grid(self, b, which, axis, **kwargs)
#    2888         cbook._check_in_list(['x', 'y', 'both'], axis=axis)
#    2889         if axis in ['x', 'both']:
# -> 2890             self.xaxis.grid(b, which=which, **kwargs)
#    2891         if axis in ['y', 'both']:
#    2892             self.yaxis.grid(b, which=which, **kwargs)
#
# ~/miniconda3/envs/py36/lib/python3.6/site-packages/matplotlib/axis.py in grid(self, b, which, **kwargs)
#    1449             elif b is not None:
#    1450                 gridkw['gridOn'] = b
# -> 1451             self.set_tick_params(which='major', **gridkw)
#    1452         self.stale = True
#    1453
#
# ~/miniconda3/envs/py36/lib/python3.6/site-packages/matplotlib/axis.py in set_tick_params(self, which, reset, **kw)
#     837                 self._major_tick_kw.update(kwtrans)
#     838                 for tick in self.majorTicks:
# --> 839                     tick._apply_params(**kwtrans)
#     840             if which in ['minor', 'both']:
#     841                 self._minor_tick_kw.update(kwtrans)
#
# ~/miniconda3/envs/py36/lib/python3.6/site-packages/matplotlib/axis.py in _apply_params(self, **kw)
#     369         if 'color' in kw:
#     370             tick_kw['markeredgecolor'] = kw['color']
# --> 371         self.tick1line.set(**tick_kw)
#     372         self.tick2line.set(**tick_kw)
#     373         for k, v in tick_kw.items():
#
# ~/miniconda3/envs/py36/lib/python3.6/site-packages/matplotlib/artist.py in set(self, **kwargs)
#    1086     def set(self, **kwargs):
#    1087         """A property batch setter.  Pass *kwargs* to set properties."""
# -> 1088         kwargs = cbook.normalize_kwargs(kwargs, self)
#    1089         move_color_to_start = False
#    1090         if "color" in kwargs:
#
# ~/miniconda3/envs/py36/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     384     @functools.wraps(func)
#     385     def wrapper(*inner_args, **inner_kwargs):
# --> 386         arguments = signature.bind(*inner_args, **inner_kwargs).arguments
#     387         if is_varargs and arguments.get(name):
#     388             warn_deprecated(
#
# ~/miniconda3/envs/py36/lib/python3.6/inspect.py in bind(*args, **kwargs)
#    2995         if the passed arguments can not be bound.
#    2996         """
# -> 2997         return args[0]._bind(args[1:], kwargs)
#    2998
#    2999     def bind_partial(*args, **kwargs):
#
# ~/miniconda3/envs/py36/lib/python3.6/inspect.py in _bind(self, args, kwargs, partial)
#    2859         return self._hash_basis() == other._hash_basis()
#    2860
# -> 2861     def _bind(self, args, kwargs, *, partial=False):
#    2862         """Private method. Don't use directly."""
#    2863
#
# KeyboardInterrupt:
